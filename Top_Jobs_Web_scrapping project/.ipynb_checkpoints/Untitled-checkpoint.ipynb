# %%
# This Program will create CSV file which Contain list of vacancises ublished by ptopjobs.lk website 

# example url " http://topjobs.lk/applicant/vacancybyfunctionalarea.jsp?FA=AGD "


from bs4 import BeautifulSoup as bf
import pandas as pd
import requests
import csv
import ast




def topjobs(url):
    link = requests.get(url).text

    soup = bf(link, 'lxml')

    f = open("jobs.csv","w", newline="")
    row_1 = ("Company_name","Post","Opening_date","Closing_date"," Job_link ")
    writer = csv.writer(f)
    writer.writerow(row_1)

    d = soup.find('div', class_='cate-lister-view')
    date = d.table.find("tr", id="tr0")

    for num in range(0,19):
        data_list_up = d.table.find("tr", id=f"tr{num}")["onclick"].split("createAlert")[1]
        res2 = ast.literal_eval(data_list_up)
        ad_link = f"http://topjobs.lk/employer/JobAdvertismentServlet?rid={res2[0]}&ac={res2[1]}&jc={res2[2]}&ec={res2[3]}&pg=applicant/vacancybyfunctionalarea.jsp',1098,631,'quickvacancysearch_1{res2[4]}"
    
        row_2 = (d.table.find("tr", id=f"tr{num}").h1.text, d.table.find("tr", id=f"tr{num}").h2.text, date.find_all('td', width="14%")[0].text, date.find_all('td', width="14%")[1].text, ad_link)
        writer.writerow(row_2)
        
        print('company name :- ', d.table.find("tr", id=f"tr{num}").h1.text)
        print('Post         :- ', d.table.find("tr", id=f"tr{num}").h2.text)
        print('Opening date :- ', date.find_all('td', width="14%")[0].text)
        print('Closing date :- ', date.find_all('td', width="14%")[1].text)
        print('link :- ', ad_link ,"\n")

    f.close()
    

    
link1 = input("input your top jobs link:-")
 
if __name__ == '__main__':
  topjobs(link1)
# Out:
# input your top jobs link:-https://www.topjobs.lk/applicant/vacancybyfunctionalarea.jsp?FA=SDQ
# company name :-  PricewaterhouseCoopers
# Post         :-  Trainee Data Analyst/ Data Analyst (2)
# Opening date :-   Thu Dec 01 2022
# Closing date :-   Wed Dec 14 2022
# link :-  http://topjobs.lk/employer/JobAdvertismentServlet?rid=0&ac=0000000311&jc=0001030005&ec=0000000410&pg=applicant/vacancybyfunctionalarea.jsp',1098,631,'quickvacancysearch_1RQvxDWPB+pLJIzLsNbC72apw
#
# company name :-  SA Ventures (Pvt) Ltd
# Post         :-  IT Trainer
# Opening date :-   Thu Dec 01 2022
# Closing date :-   Wed Dec 14 2022
# link :-  http://topjobs.lk/employer/JobAdvertismentServlet?rid=1&ac=DEFZZZ&jc=0001029977&ec=DEFZZZ&pg=applicant/vacancybyfunctionalarea.jsp',1098,631,'quickvacancysearch_1RQvxDWPB+pLJIzLsNbC72apw
#
# company name :-  Epic Technology Group
# Post         :-  Senior Software Engineer  - .Net Core
# Opening date :-   Thu Dec 01 2022
# Closing date :-   Wed Dec 14 2022
# link :-  http://topjobs.lk/employer/JobAdvertismentServlet?rid=2&ac=0000000484&jc=0001029964&ec=0000000651&pg=applicant/vacancybyfunctionalarea.jsp',1098,631,'quickvacancysearch_1RQvxDWPB+pLJIzLsNbC72apw
#
# company name :-  Aussee Oats Milling (Pvt) Ltd
# Post         :-  IT Executive - Web Development
# Opening date :-   Thu Dec 01 2022
# Closing date :-   Wed Dec 14 2022
# link :-  http://topjobs.lk/employer/JobAdvertismentServlet?rid=3&ac=DEFZZZ&jc=0001029947&ec=DEFZZZ&pg=applicant/vacancybyfunctionalarea.jsp',1098,631,'quickvacancysearch_1RQvxDWPB+pLJIzLsNbC72apw
#
# company name :-  POTENZA Pvt Limited
# Post         :-  Associate Software Engineer
# Opening date :-   Thu Dec 01 2022
# Closing date :-   Wed Dec 14 2022
# link :-  http://topjobs.lk/employer/JobAdvertismentServlet?rid=4&ac=DEFZZZ&jc=0001029928&ec=DEFZZZ&pg=applicant/vacancybyfunctionalarea.jsp',1098,631,'quickvacancysearch_1RQvxDWPB+pLJIzLsNbC72apw
#
# company name :-   Futura Tech Labs
# Post         :-  Software Engineer
# Opening date :-   Thu Dec 01 2022
# Closing date :-   Wed Dec 14 2022
# link :-  http://topjobs.lk/employer/JobAdvertismentServlet?rid=5&ac=DEFZZZ&jc=0001029927&ec=DEFZZZ&pg=applicant/vacancybyfunctionalarea.jsp',1098,631,'quickvacancysearch_1RQvxDWPB+pLJIzLsNbC72apw
#
# company name :-  eMarketingEye (Pvt) Limited
# Post         :-  Full Stack Web Developer
# Opening date :-   Thu Dec 01 2022
# Closing date :-   Wed Dec 14 2022
# link :-  http://topjobs.lk/employer/JobAdvertismentServlet?rid=6&ac=0000000197&jc=0001029914&ec=0000000233&pg=applicant/vacancybyfunctionalarea.jsp',1098,631,'quickvacancysearch_1RQvxDWPB+pLJIzLsNbC72apw
#
# company name :-  eMarketingEye (Pvt) Limited
# Post         :-  Senior Web Designer
# Opening date :-   Thu Dec 01 2022
# Closing date :-   Wed Dec 14 2022
# link :-  http://topjobs.lk/employer/JobAdvertismentServlet?rid=7&ac=0000000197&jc=0001029913&ec=0000000233&pg=applicant/vacancybyfunctionalarea.jsp',1098,631,'quickvacancysearch_1RQvxDWPB+pLJIzLsNbC72apw
#
# company name :-  Inspired Business Solutions
# Post         :-  Interns  - Software Engineering / IT
# Opening date :-   Thu Dec 01 2022
# Closing date :-   Wed Dec 14 2022
# link :-  http://topjobs.lk/employer/JobAdvertismentServlet?rid=8&ac=DEFZZZ&jc=0001029907&ec=DEFZZZ&pg=applicant/vacancybyfunctionalarea.jsp',1098,631,'quickvacancysearch_1RQvxDWPB+pLJIzLsNbC72apw
#
# company name :-  VitalHub (Pvt) Ltd
# Post         :-  Spring Boot/ Python/ AWS Full Stack Engineer
# Opening date :-   Thu Dec 01 2022
# Closing date :-   Wed Dec 14 2022
# link :-  http://topjobs.lk/employer/JobAdvertismentServlet?rid=9&ac=DEFZZZ&jc=0001029901&ec=DEFZZZ&pg=applicant/vacancybyfunctionalarea.jsp',1098,631,'quickvacancysearch_1RQvxDWPB+pLJIzLsNbC72apw
#
# company name :-  Enadoc Pvt Limited
# Post         :-  Associate Software Engineer
# Opening date :-   Thu Dec 01 2022
# Closing date :-   Wed Dec 14 2022
# link :-  http://topjobs.lk/employer/JobAdvertismentServlet?rid=10&ac=DEFZZZ&jc=0001029899&ec=DEFZZZ&pg=applicant/vacancybyfunctionalarea.jsp',1098,631,'quickvacancysearch_1RQvxDWPB+pLJIzLsNbC72apw
#
# company name :-  Enadoc Pvt Limited
# Post         :-  Quality Assurance Engineer
# Opening date :-   Thu Dec 01 2022
# Closing date :-   Wed Dec 14 2022
# link :-  http://topjobs.lk/employer/JobAdvertismentServlet?rid=11&ac=DEFZZZ&jc=0001029898&ec=DEFZZZ&pg=applicant/vacancybyfunctionalarea.jsp',1098,631,'quickvacancysearch_1RQvxDWPB+pLJIzLsNbC72apw
#
# company name :-  Enadoc Pvt Limited
# Post         :-  Tech Lead
# Opening date :-   Thu Dec 01 2022
# Closing date :-   Wed Dec 14 2022
# link :-  http://topjobs.lk/employer/JobAdvertismentServlet?rid=12&ac=DEFZZZ&jc=0001029897&ec=DEFZZZ&pg=applicant/vacancybyfunctionalarea.jsp',1098,631,'quickvacancysearch_1RQvxDWPB+pLJIzLsNbC72apw
#
# company name :-  Jobfactory
# Post         :-  Technical Lead-.NET (1)
# Opening date :-   Thu Dec 01 2022
# Closing date :-   Wed Dec 14 2022
# link :-  http://topjobs.lk/employer/JobAdvertismentServlet?rid=13&ac=0000000375&jc=0001029888&ec=0000000492&pg=applicant/vacancybyfunctionalarea.jsp',1098,631,'quickvacancysearch_1RQvxDWPB+pLJIzLsNbC72apw
#
# company name :-  Jobfactory
# Post         :-  Technical Lead-JavaScript (1)
# Opening date :-   Thu Dec 01 2022
# Closing date :-   Wed Dec 14 2022
# link :-  http://topjobs.lk/employer/JobAdvertismentServlet?rid=14&ac=0000000375&jc=0001029887&ec=0000000492&pg=applicant/vacancybyfunctionalarea.jsp',1098,631,'quickvacancysearch_1RQvxDWPB+pLJIzLsNbC72apw
#
# company name :-  VitalHub (Pvt) Ltd
# Post         :-  Java Full Stack Engineers
# Opening date :-   Thu Dec 01 2022
# Closing date :-   Wed Dec 14 2022
# link :-  http://topjobs.lk/employer/JobAdvertismentServlet?rid=15&ac=DEFZZZ&jc=0001029877&ec=DEFZZZ&pg=applicant/vacancybyfunctionalarea.jsp',1098,631,'quickvacancysearch_1RQvxDWPB+pLJIzLsNbC72apw
#
# company name :-  Jobfactory
# Post         :-  .NET Tech Lead  (1)
# Opening date :-   Thu Dec 01 2022
# Closing date :-   Wed Dec 14 2022
# link :-  http://topjobs.lk/employer/JobAdvertismentServlet?rid=16&ac=0000000375&jc=0001029876&ec=0000000492&pg=applicant/vacancybyfunctionalarea.jsp',1098,631,'quickvacancysearch_1RQvxDWPB+pLJIzLsNbC72apw
#
# company name :-  Jobfactory
# Post         :-   Tech Lead (1)
# Opening date :-   Thu Dec 01 2022
# Closing date :-   Wed Dec 14 2022
# link :-  http://topjobs.lk/employer/JobAdvertismentServlet?rid=17&ac=0000000375&jc=0001029875&ec=0000000492&pg=applicant/vacancybyfunctionalarea.jsp',1098,631,'quickvacancysearch_1RQvxDWPB+pLJIzLsNbC72apw
#
# company name :-  Jobfactory
# Post         :-  Developer iOS (1)
# Opening date :-   Thu Dec 01 2022
# Closing date :-   Wed Dec 14 2022
# link :-  http://topjobs.lk/employer/JobAdvertismentServlet?rid=18&ac=0000000375&jc=0001029872&ec=0000000492&pg=applicant/vacancybyfunctionalarea.jsp',1098,631,'quickvacancysearch_1RQvxDWPB+pLJIzLsNbC72apw
