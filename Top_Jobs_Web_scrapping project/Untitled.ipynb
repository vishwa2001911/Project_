# %%
# This Program will create CSV file which Contain list of vacancises ublished by ptopjobs.lk website 

# example url " http://topjobs.lk/applicant/vacancybyfunctionalarea.jsp?FA=AGD "


from bs4 import BeautifulSoup as bf
import pandas as pd
import requests
import csv




def topjobs(url):
    link = requests.get(url).text

    soup = bf(link, 'lxml')

    f = open("jobs.csv","w", newline="")
    row_1 = ("Company_name","Post","Opening_date","Closing_date",f"Job_link:- {url}")
    writer = csv.writer(f)
    writer.writerow(row_1)

    d = soup.find('div', class_='cate-lister-view')
    date = d.table.find("tr", id="tr0")

    for num in range(0,19):
        row_2 = (d.table.find("tr", id=f"tr{num}").h1.text, d.table.find("tr", id=f"tr{num}").h2.text, date.find_all('td', width="14%")[0].text, date.find_all('td', width="14%")[1].text,None)
        writer.writerow(row_2)
        print('company name :- ', d.table.find("tr", id=f"tr{num}").h1.text)
        print('Post         :- ', d.table.find("tr", id=f"tr{num}").h2.text)
        print('Opening date :- ', date.find_all('td', width="14%")[0].text)
        print('Closing date :- ', date.find_all('td', width="14%")[1].text,"\n")

    f.close()
    

    
link1 = input("input your top jobs link:-")
 
if __name__ == '__main__':
  topjobs(link1)
# Out:
# input your top jobs link:-http://topjobs.lk/applicant/vacancybyfunctionalarea.jsp?FA=AGD
# company name :-  KPMG Executive Search Private Limited
# Post         :-  Marketing Manager ? Animal Nutrition and Health (1)
# Opening date :-   Tue Oct 04 2022
# Closing date :-   Sun Oct 16 2022
#
# company name :-  Lankem Ceylon PLC
# Post         :-  Management Trainee - Agro (3)
# Opening date :-   Tue Oct 04 2022
# Closing date :-   Sun Oct 16 2022
#
# company name :-  MJF Group
# Post         :-  Senior Executive - Programmes - Dilmah Conservation (1)
# Opening date :-   Tue Oct 04 2022
# Closing date :-   Sun Oct 16 2022
#
# company name :-  Thalahena Agri Business
# Post         :-  Farm Manager
# Opening date :-   Tue Oct 04 2022
# Closing date :-   Sun Oct 16 2022
#
# company name :-  Rathna Agro Plantation (Pvt) Ltd
# Post         :-  Manager - Mango Plantation / Field Officers
# Opening date :-   Tue Oct 04 2022
# Closing date :-   Sun Oct 16 2022
#
# company name :-  Rathna Group of Companies
# Post         :-  Food Technologist
# Opening date :-   Tue Oct 04 2022
# Closing date :-   Sun Oct 16 2022
#
# company name :-  Santani Wellness Resort and Spa
# Post         :-  Farm Manager
# Opening date :-   Tue Oct 04 2022
# Closing date :-   Sun Oct 16 2022
#
# company name :-  BLUESTEPS
# Post         :-  Assistant Manager - Business Development (Export Market for Organic Food & Beverage Products) (1)
# Opening date :-   Tue Oct 04 2022
# Closing date :-   Sun Oct 16 2022
#
# company name :-  Sarabhumi Lanka Bio Products (Pvt) Ltd
# Post         :-  Executive - Administrative
# Opening date :-   Tue Oct 04 2022
# Closing date :-   Sun Oct 16 2022
#
# company name :-  Ethimale Plantation (Pvt) Ltd
# Post         :-  Agriculture Resident Manager
# Opening date :-   Tue Oct 04 2022
# Closing date :-   Sun Oct 16 2022
#
# company name :-  Upcot Green Fields (Pvt) Ltd
# Post         :-  Creeper Trainee - Maskeliya Upcot
# Opening date :-   Tue Oct 04 2022
# Closing date :-   Sun Oct 16 2022
#
# company name :-  Ceylon Cold Stores PLC
# Post         :-  Executive - Quality Assurance (1)
# Opening date :-   Tue Oct 04 2022
# Closing date :-   Sun Oct 16 2022
#
# company name :-  GT Agro
# Post         :-  Assistant Farm Manager
# Opening date :-   Tue Oct 04 2022
# Closing date :-   Sun Oct 16 2022
#
# company name :-  Otium (Pvt) Ltd
# Post         :-  Agriculture Specialist
# Opening date :-   Tue Oct 04 2022
# Closing date :-   Sun Oct 16 2022
#
# company name :-  Ceylon Fresh Fields Exports (Private) Limited
# Post         :-  Agronomists
# Opening date :-   Tue Oct 04 2022
# Closing date :-   Sun Oct 16 2022
#
# company name :-  MJF Group
# Post         :-  Senior Executive - Programmes - Dilmah Conservation
# Opening date :-   Tue Oct 04 2022
# Closing date :-   Sun Oct 16 2022
#
# company name :-  Shaw Wallace Ceylon Ltd (Ekala)
# Post         :-  Agriculture Extension Executive (Cassava, Grains, Spices)
# Opening date :-   Tue Oct 04 2022
# Closing date :-   Sun Oct 16 2022
#
# company name :-  Jay Jay Mills Lanka (Pvt) Ltd
# Post         :-  Executive - Agriculture
# Opening date :-   Tue Oct 04 2022
# Closing date :-   Sun Oct 16 2022
#
# company name :-  Ultrakil Pest Management Co. (Pvt) Ltd
# Post         :-  Pest Management Executive
# Opening date :-   Tue Oct 04 2022
# Closing date :-   Sun Oct 16 2022
